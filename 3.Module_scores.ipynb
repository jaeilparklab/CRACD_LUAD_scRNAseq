# %%
Nanog_target_genes = ['Cdh2',
'Naalad2',
'Acot8',
'Abcf2',
'Snupn',
'Gpc6',
'Actr1b',
'Actr1a',
'Sugp2',
'Cebpz',
'Chst4',
'Rbm7',
'Cdk6',
'Ddx39a',
'Psmd14',
'Spry1',
'Adar',
'Katnb1',
'Trim22',
'Hmg20a',
'Cited2',
'Cept1',
'Yap1',
'Timm23b',
'Rbm14',
'Hmgn4',
'Sema4f',
'Sema3c',
'Ddx17',
'Nebl',
'Anp32b',
'Cct7',
'Sorbs1',
'Ahsa1',
'Usp16',
'Polr3g',
'Trim16',
'Pdpn',
'Gas2l1',
'Lefty1',
'Igf2bp3',
'Khdrbs1',
'Celf2',
'Gna13',
'Cct6b',
'Cetn3',
'Cfl1',
'Oga',
'Nfat5',
'Rai1',
'Sec24a',
'Utp14a',
'Faxdc2',
'Nmu',
'Blcap',
'Tcerg1',
'Morf4l1',
'Msl3',
'Serinc3',
'Tmed10',
'Kdelr3',
'Ift27',
'Rbpms',
'Pim2',
'Abhd2',
'Chd2',
'Cnmd',
'Dido1',
'Hnrnpul1',
'Krr1',
'Foxn3',
'Pwp1',
'Il1rapl1',
'Pkig',
'Nudt5',
'Wdhd1',
'Wdr6',
'Fzd10',
'Ddx20',
'Rnf24',
'Egln3',
'Cavin3',
'Sat2',
'Mrap2',
'Dusp12',
'Cfap36',
'Mtfr2',
'Cope',
'Gpn1',
'Cbx3',
'Oip5',
'Dtx2',
'Stk11ip',
'Osbpl1a',
'Tmem123',
'Tlcd1',
'Lypd1',
'Cks2',
'Scgb3a2',
'Clic1',
'Add3',
'Cln3',
'Slc36a4',
'Cyp2r1',
'Lrig3',
'Naa30',
'Plin2',
'Cep20',
'Iqck',
'Ubald1',
'Tmem170a',
'Hexim2',
'Wdr81',
'Ino80c',
'Cnn2',
'Cnn3',
'Tyw3',
'Znf684',
'Tceanc2',
'Dram2',
'Col4a5',
'Col4a6',
'Col7a1',
'Mboat2',
'Col12a1',
'Osr1',
'Zfp42',
'Aasdh',
'Cox6a1',
'Grpel2',
'Wdr36',
'Cibar1',
'Cpt1a',
'Unc5d',
'C20orf96',
'Romo1',
'Cryz',
'Cs',
'Mapk14',
'Hectd2',
'Znf664',
'C12orf60',
'Fbxl14',
'Csnk1e',
'Vcan',
'Cstf1',
'Cstf3',
'Icmt-dt',
'Slc30a7',
'Znf436-as1',
'Ccn2',
'Commd7',
'Ctsv',
'Ccdc12',
'Glipr2',
'Cxadr',
'Marveld2',
'Irx2',
'Cyld',
'Cyp1b1',
'Amotl1',
'Grk3',
'Tdrp',
'Ap2a1',
'Spred1',
'Adal',
'Retreg3',
'Ap1g1',
'Dcx',
'Ddx5',
'Dmxl1',
'Asxl1',
'Dhcr7',
'Dnm2',
'Dpagt1',
'Dpysl2',
'Dpysl3',
'Dtna',
'Dusp6',
'Dvl2',
'E2f3',
'Higd2a',
'Eef2',
'Eif4b',
'Eif4g2',
'Thap8',
'Ensa',
'Epha1',
'Ak4',
'Triml2',
'Erbb2',
'Ercc1',
'Erh',
'Extl2',
'Alcam',
'Fanca',
'Acsl4',
'Fancf',
'Fbln1',
'Farsa',
'Fat1',
'Abcb7',
'Ddias',
'Fam124a',
'Fdps',
'Znrf2',
'Gpc4',
'Fgf2',
'Fgfr1',
'Fgfr2',
'Fhit',
'Fkbp1b',
'Dnajc8',
'Ell2',
'Dkk1',
'Slc4a1ap',
'Tpx2',
'Nt5c2',
'Kdm2a',
'Wdtc1',
'Foxo1',
'Avl9',
'Exph5',
'Foxo3',
'Spart',
'Phf8',
'Septin6',
'Kank1',
'Rrs1',
'Sulf1',
'Dnajc9',
'Klhl18',
'Fbxw11',
'Ehbp1',
'Sin3b',
'Nedd4l',
'Sash1',
'Dnajc16',
'Obsl1',
'Smg5',
'Ecpas',
'Frat2',
'Cotl1',
'Commd3',
'Slc44a1',
'Sf3b1',
'Icmt',
'Cbx5',
'Iscu',
'Leprotl1',
'Hey2',
'Kctd2',
'R3hdm1',
'Znf281',
'Rbfox2',
'Cdc42ep4',
'Orc6',
'Mkrn1',
'Ssbp2',
'Ssbp3',
'Slc7a11',
'Lsm5',
'Sgk3',
'Rab38',
'Gspt2',
'Tmem245',
'Fus',
'Fzd2',
'Rab3gap2',
'Rad54b',
'Bambi',
'Arih1',
'Mettl7a',
'Galk2',
'Dcaf13',
'Polr1a',
'Znf473',
'Dpcd',
'Sgms1',
'Znf521',
'Clic4',
'Dnaaf9',
'Ganc',
'Pnisr',
'Tmem87a',
'Tbc1d10b',
'Gorasp2',
'Plekhg3',
'Ppp1r16b',
'Gga1',
'Prpf31',
'Trpc4ap',
'Kif26a',
'Gart',
'Phgdh',
'Gata6',
'Bscl2',
'Hbp1',
'Gja1',
'Dnajc2',
'Ankrd1',
'Stk36',
'Sall3',
'Gla',
'Serp1',
'Lsm3',
'Apex2',
'Tnrc6a',
'Golim4',
'Ube2s',
'Prpf19',
'Glg1',
'Poll',
'Mat2b',
'Glud1',
'Gnai1',
'Gng10',
'Golga4',
'Bcl9l',
'Gxylt1',
'Ubald2',
'Angpt1',
'Zik1',
'C19orf54',
'Wdr62',
'Rabl3',
'Atp11c',
'Bzw2',
'Mcts1',
'Atad2',
'Hapstr1',
'Ube2t',
'Tmem208',
'Tbk1',
'Gsk3a',
'Gstt2',
'Gtf2e1',
'Gtf2h2',
'Cyp2s1',
'Uqcr10',
'Tfpt',
'Nme7',
'Gypc',
'Lmcd1',
'Slc40a1',
'Anxa1',
'H2ax',
'H2az1',
'H2bc5',
'Has2',
'Hells',
'Ehd4',
'Hhex',
'Hnrnpa1',
'Hnrnpa2b1',
'Hnrnph2',
'Hoxb5',
'Hspa4',
'Hspa5',
'Aplp2',
'Apoa2',
'Tnc',
'Apob',
'Id1',
'Id2',
'Acadm',
'Idh3a',
'Ifi16',
'Amigo2',
'Ska2',
'Igfbp2',
'Igfbp3',
'Ccn1',
'Aqp2',
'Ilf2',
'Ilf3',
'Ing1',
'Inpp4a',
'Itgb1',
'Jarid2',
'Jun',
'Jup',
'Tmem205',
'Rab15',
'Arf3',
'Arf4',
'Kcnn2',
'Kdr',
'Kpna3',
'Tnpo1',
'Slc7a5p2',
'Krt18',
'Shisa6',
'Ier5l',
'Acat2',
'Lama4',
'Arhgap1',
'Pcnx3',
'Vwa5a',
'Lrp2',
'Lrp3',
'Nbr1',
'Smad3',
'Man2c1',
'Mcc',
'Mdh1',
'Mef2a',
'Asah1',
'Mica',
'Micb',
'Mlh1',
'Map3k11',
'Mmp2',
'Mmp9',
'Mobp',
'Mov10',
'Mre11',
'Msh2',
'Mtm1',
'Nap1l2',
'Atf4',
'Ndufb3',
'Ndufs2',
'Nktr',
'Nmt1',
'Nodal',
'Pnp',
'Npas2',
'Ror1',
'Nvl',
'Oaz2',
'Orc1',
'Aco2',
'Oxa1l',
'P4ha1',
'Myef2',
'Ak3',
'Pdcl',
'F11r',
'Pbx1',
'Pcbp1',
'Emc9',
'Desi2',
'Ndufa13',
'Klhl5',
'Ift52',
'Zc2hc1a',
'Aph1a',
'Pcna',
'Hsd17b12',
'Ing4',
'Jpt1',
'Ss18l2',
'Nusap1',
'Vrk3',
'Ccdc174',
'Mrpl37',
'Pbdc1',
'Mrpl27',
'Pipox',
'Cdk16',
'Cdk17',
'Armcx1',
'Tnfrsf12a',
'Ubr5',
'Nip7',
'Ddx41',
'Nop16',
'Atp5pb',
'Lars1',
'Ufm1',
'Gde1',
'Larp7',
'Pdhb',
'Asb1',
'Saraf',
'Pals2',
'Enpp2',
'Sufu',
'Uimc1',
'Wbp11',
'Pex1',
'Cdk14',
'Atp6v1a',
'Serpina1',
'Pik3r2',
'Pitx2',
'Nup54',
'Fxyd5',
'Myo3a',
'Exosc9',
'Ppil3',
'Podxl',
'Zfand6',
'Pou2f1',
'Ccdc93',
'Shld2',
'Ddx49',
'Pou4f1',
'Pou5f1',
'Mindy2',
'Rrn3',
'Dym',
'Wbp1l',
'Lrrc49',
'Ankrd49',
'Elp6',
'Nsd3',
'Rpp25',
'Zscan32',
'Tmem160',
'Hcfc1r1',
'Znf770',
'Pih1d1',
'Ppp2r3c',
'Prpf39',
'Ptcd3',
'Ppp1r2',
'Rnf31',
'Fancl',
'Akirin2',
'Thap1',
'Dars2',
'Ppp2r1a',
'Rif1',
'Ric8b',
'Ppp2r1b',
'Nadsyn1',
'Resf1',
'Rprd1a',
'Dppa4',
'Exd2',
'Ppp2r3a',
'Vrtn',
'Ppp2r5c',
'Ube2w',
'Rnf121',
'Slc39a9',
'Znf331',
'Prcp',
'Ndufaf7',
'Etnk1',
'Fem1a',
'Otub1',
'Fermt1',
'Osgep',
'Iws1',
'Rbm22',
'Pkib',
'Yju2',
'Vps35',
'Naxd',
'Znf701',
'H2aj',
'Prr11',
'Foxj2',
'Kdm3a',
'Cand1',
'Ubap2',
'Wwc3',
'Brk1',
'Cisd1',
'Psenen',
'Apom',
'Lin37',
'Gng12',
'Mapk8',
'Klhl4',
'Nsmce3',
'Prnp',
'Kiaa1217',
'Eif4enif1',
'Prss8',
'Psen2',
'Cfap298',
'B2m',
'Psma1',
'Gripap1',
'Emc7',
'Psmb1',
'Ubqln4',
'Exosc5',
'Smarcad1',
'Psmb4',
'Gpr108',
'Fem1c',
'Psmb5',
'Olfml3',
'Xab2',
'Otud7b',
'Fam20c',
'Kif15',
'Psmc2',
'Ankmy2',
'Rab25',
'Ints12',
'Psmd9',
'Phtf2',
'Znf286a',
'Kiaa1143',
'Scaf4',
'Odf2l',
'Arid1b',
'Znf398',
'Slain2',
'Ranbp10',
'Lrrn1',
'Ptn',
'Cachd1',
'Ptpn1',
'Ptpn2',
'Ano8',
'Igdcc4',
'Gatad1',
'Pex2',
'Scaf1',
'Eps15l1',
'Abracl',
'Qars1',
'Bcat1',
'Rab5a',
'Rab5b',
'Rad23a',
'Rangap1',
'Rap1a',
'Rarb',
'Rasa1',
'Rasgrf2',
'Rbbp4',
'Bckdha',
'Senp2',
'Rbm4',
'Rbp1',
'Rest',
'Rfx1',
'Rgs10',
'Exoc4',
'Rnf2',
'Sav1',
'Nif3l1',
'Bcl9',
'Rpl17',
'Rpl21',
'Rpl32',
'Rplp1',
'Rps3a',
'Rps13',
'Rps18',
'Rps26',
'Rps27a',
'Ryr3',
'S100a11',
'Vps52',
'Sall2',
'Sall1',
'Sc5d',
'Scnn1a',
'Sdc4',
'Vipas39',
'Nsun3',
'Prdm14',
'Perp',
'Lhpp',
'Selenop',
'Kif9',
'Set',
'Tfb2m',
'Sfrp1',
'Sfrp2',
'Rab17',
'Srsf4',
'Noc3l',
'Rnf25',
'Dclre1c',
'Inf2',
'Ttc31',
'Sgk1',
'Scg5',
'Nucks1',
'C11orf1',
'St3gal2',
'Marchf7',
'Pmel',
'Skil',
'Bmp2',
'Slc1a1',
'Nol6',
'Tmem135',
'Rsrc2',
'Mzt2a',
'Fam72b',
'Bmp7',
'Hltf',
'Plekha3',
'Rasl11b',
'Tmem108',
'Polr3d',
'Bnip1',
'Snrnp70',
'Snrpa',
'Snrpe',
'Snrpn',
'Snx1',
'Son',
'Sox2',
'Sp2',
'Sparc',
'Zfp36l1',
'Stat3',
'Stc1',
'Aurka',
'Strn',
'Stxbp2',
'Supt4h1',
'Taf4b',
'Klf5',
'Taf12',
'Tal1',
'Taldo1',
'Tarbp2',
'Tbcc',
'Tbl1x',
'Tbp',
'Tcf7l2',
'Tcf20',
'Tdgf1',
'Bub1b',
'Terf1',
'Lefty2',
'Thbs2',
'Tia1',
'Tial1',
'Tiam1',
'Timp4',
'Tle2',
'Tle3',
'Tspan6',
'Top2a',
'Eipr1',
'Ttf1',
'Tubg1',
'Txnrd1',
'Ubc',
'Ube2d3',
'Sumo1',
'Ubp1',
'Ufd1',
'Vim',
'Vldlr',
'Vrk2',
'Wars1',
'Wee1',
'Zic1',
'Zic2',
'Zic3',
'Cnbp',
'Ca2',
'Ca4',
'Znf174',
'Cacna1a',
'Znf185',
'Znf202',
'Znf217',
'Znf226',
'Znf112',
'Map3k12',
'Cacna2d1',
'Usp7',
'Scnm1',
'Slx1b',
'Dda1',
'Kctd15',
'Secisbp2',
'Tmem109',
'Dscc1',
'Wdr77',
'Smim7',
'Phf23',
'Gnptab',
'Bag6',
'Tmem43',
'Calb1',
'Lrfn3',
'Cars2',
'Obi1',
'Vcpkmt',
'Hmbox1',
'C1orf54',
'Akirin1',
'Hspbap1',
'Parp8',
'Igflr1',
'Tbl1xr1',
'Palb2',
'Isoc2',
'Katnbl1',
'Fbxo31',
'Alg9',
'Gstcd',
'Mob3b',
'Clmp',
'Mettl8',
'Dcakd',
'Caap1',
'Nanog',
'Cntnap3',
'Kat6a',
'Dhdds',
'Jade1',
'Grhl2',
'Dnajb14',
'Cald1',
'Psme3ip1',
'Uxs1',
'Golga2p10',
'Mus81',
'Mllt10',
'Wdcp',
'Dcaf11',
'Calm2',
'Cyb5b',
'Fxr1',
'Calr',
'Anp32a',
'Slc7a5',
'Vopp1',
'C1orf21',
'Txndc5',
'Urm1',
'Map1lc3b',
'Med25',
'Slirp',
'Slc7a5p1',
'Mkks',
'Capza2',
'Picalm',
'Axin2',
'Cdc7',
'Cdc45',
'Eomes',
'Fzd7',
'Fzd8',
'H2ac18',
'Tcf7l1',
'Sf3b5',
'Abhd11',
'H4c3',
'Eif2a',
'Usp44',
'Tomm40l',
'Arid5b',
'Ascc2',
'Ciao2a',
'Casp9',
'Traf7',
'Dcun1d5',
'Alkbh7',
'Chchd5',
'Naa38',
'Coa8',
'Spire2',
'Dctn5',
'Ttf2',
'Gtpbp3',
'Mpv17l2',
'Sft2d3',
'Ado',
'Zscan10',
'Lingo1',
'Slc49a4',
'Atg4c',
'Prpf38a',
'Ppfibp1',
'Ajuba',
'Tmem60',
'Smim3',
'Parg',
'Zcchc3',
'Zcrb1',
'Ap3b1',
'Cdc14b',
'Cav1',
'Khsrp',
'Klf7',
'Plpp1',
'Runx1t1',
'Eif3d',
'Eif3f',
'Pea15',
'B3galt4',
'Serpinh1',
'Gbf1',
'Ripk1',
'Cds2',
'Mtmr1',
'Mpdz',
'Trim24',
'Dpm1',
'Hesx1',
'Alkbh1',
'Tsc22d1',
'Cdc123',
'Cdc16',
'Ddx18',
'Ap1s2',
'Rspry1',
'Dph6',
'Znf551',
'Spag9',
'Nfs1',
'Papss2',
'Cldn6',
'Cep95',
'Pip4p1',
'Tceal8',
'Pkmyt1',
'Usp10',
'Sec22c',
'Tmem259',
'Nemf',
'Tmsb10',
'Smdt1',
'Cables1',
'Wdr20',
'Bub3',
'Cog7',
'Znf300',
'Large1',
'Vapb',
'Nolc1',
'Lrat',
'Pnma1',
'Msc',
'Dhrs3',
'H2ac25',
'Pgap3',
'Trip10',
'Trip4',
'Gtf3c4',
'B4galt6',
'Cnot8',
'Armc6',
'Cer1',
'Atp5if1',
'Ddx23',
'Cdyl',
'Med23',
'Eif2ak3',
'Pigl',
'Eef1e1',
'Tmem59',
'Bag5',
'Entpd1',
'Atp6v1g1',
'Sec22b',
'Gtpbp1',
'Gdf3',
'Prepl',
'Rbm39',
'Nfe2l3',
'Ncor1',
'Fez1',
'Morf4l2',
'Znf516',
'Prorp',
'Fam131b',
'Tmem63a',
'Sart3',
'Kntc1',
'Tcaf1',
'Pclaf',
'Bclaf1',
'Atg13',
'Dhx38',
'Dlgap5',
'Sfi1',
'Tsc22d2',
'Arhgap11a',
'Cdk1',
'Lcmt2',
'Zeb2',
'Epm2aip1',
'Supt7l',
'Ncapd2',
'Josd1',
'Usp3',
'Med12',
'Cdh1']

# %%
Sox2_target_genes = ['Cdh2',
'Naalad2',
'Acot8',
'Cdh3',
'Abcf2',
'Dpp3',
'Huwe1',
'Gpc6',
'Actr1a',
'G3bp1',
'Sugp2',
'Cdk6',
'Ddx39a',
'Mrps31',
'Adar',
'Trim22',
'Hmg20a',
'Timm23b',
'Vat1',
'Ddx17',
'Nebl',
'Anp32b',
'Arfgef1',
'Polr3g',
'Trim16',
'Pdpn',
'Lefty1',
'Exoc5',
'Igf2bp3',
'Gna13',
'Cetn3',
'Cfl1',
'Oga',
'Rbbp9',
'Sdccag8',
'Faxdc2',
'Nmu',
'Gadd45g',
'Maged2',
'Morf4l1',
'Msl3',
'Clp1',
'Mapre2',
'Kif2c',
'Rbpms',
'Ube2c',
'Dido1',
'Hnrnpul1',
'Foxn3',
'Pwp1',
'Ficd',
'Nudt4',
'Fzd10',
'Rnf24',
'Egln3',
'Cavin3',
'Dusp12',
'Cbx3',
'Oip5',
'Osbpl1a',
'Tmem123',
'Wdfy2',
'Lypd1',
'Add3',
'Cln3',
'Naa30',
'Plin2',
'Tmem170a',
'Hexim2',
'Wdr81',
'Ino80c',
'Znf428',
'Ndufa11',
'Col12a1',
'Copb1',
'Aasdh',
'Wdr36',
'Cpt1a',
'C20orf96',
'Hectd2',
'Xrra1',
'Fam76b',
'Znf664',
'C12orf60',
'Fbxl14',
'Csnk1e',
'Vcan',
'Ppm1n',
'Creb3l4',
'Icmt-dt',
'Ccn2',
'Cth',
'Commd7',
'Irx2',
'Amotl1',
'Grk3',
'Rdh10',
'Fbxo16',
'Tdrp',
'Tstd2',
'Ap2a1',
'Spred1',
'Retreg3',
'Sde2',
'Ddx5',
'Dnm2',
'Dpagt1',
'Dpysl2',
'Dpysl3',
'Dtna',
'Dusp6',
'Dvl2',
'E2f3',
'Eef2',
'Egr3',
'Ubr1',
'Eif4g2',
'Elavl2',
'Ensa',
'Tubb',
'Epha1',
'Triml2',
'Erbb2',
'Alcam',
'Fancc',
'Fancf',
'Farsa',
'Abcb7',
'Fam124a',
'Oard1',
'Fgf2',
'Fgfr1',
'Fgfr2',
'Mtf2',
'Adgrl1',
'Dkk1',
'Mast1',
'Acin1',
'Cep131',
'Foxo1',
'Exph5',
'Mrps27',
'Phf8',
'Ncdn',
'Septin6',
'Zcchc14',
'Kank1',
'Fam168a',
'Rrs1',
'Sulf1',
'Nup160',
'Fbxw11',
'Nedd4l',
'Sash1',
'Dnajc16',
'Obsl1',
'Ecpas',
'Pip5k1c',
'Frat2',
'Commd3',
'Slc44a1',
'Icmt',
'Cbx5',
'Ethe1',
'Znf281',
'Orc6',
'Ppp1r15a',
'Ssbp3',
'Slc7a11',
'Sgk3',
'Gspt2',
'Tmem245',
'Alpl',
'Ftl',
'Fus',
'Fzd2',
'Cby1',
'Rab3gap2',
'Rad54b',
'Lsm4',
'Bambi',
'Arih1',
'Abtb2',
'Usp49',
'Sgms1',
'Clic4',
'Fam98a',
'Dnaaf9',
'Pnisr',
'Tbc1d10b',
'Plekhg3',
'Gga1',
'Kifbp',
'Trpc4ap',
'Kif26a',
'Timm9',
'Timm8b',
'Hbp1',
'Gja1',
'Dnajc2',
'Ankrd1',
'Foxp1',
'Tjp3',
'Ago2',
'Slc39a1',
'Lsm3',
'Tnrc6a',
'Prpf19',
'Kcnmb4',
'Mat2b',
'Gnai1',
'Gng10',
'Pgm2l1',
'Gxylt1',
'Ubald2',
'Zik1',
'C19orf54',
'Nkiras1',
'Grk6',
'Grid2',
'Lamtor2',
'Aamdc',
'Mrps18b',
'Mcts1',
'Atad2',
'Mrpl15',
'Ube2t',
'Cfap20',
'Scg3',
'Gsk3a',
'Gsk3b',
'Usp25',
'Uqcr10',
'Tra2a',
'Nme7',
'H2ax',
'H3-3b',
'Has2',
'Hdac2',
'Hells',
'Hhex',
'Hmox1',
'Hnrnpa1',
'Hnrnpa2b1',
'Hnrnpc',
'Hnrnpk',
'Hnrnpl',
'Apex1',
'Hsp90ab1',
'Tnc',
'C1orf174',
'Id1',
'Idh3g',
'Ifi16',
'Znf677',
'Ska2',
'Igfbp2',
'Ccn1',
'App',
'Ik',
'Aqp2',
'Ilf2',
'Ilf3',
'Inhba',
'Jarid2',
'Jup',
'Rab15',
'Arf3',
'Arf4',
'Kcnn2',
'Arl4d',
'Kdr',
'Kif11',
'Kpna3',
'Slc7a5p2',
'Ier5l',
'Lama4',
'Arhgap1',
'Lasp1',
'Ablim1',
'Pcnx3',
'Vwa5a',
'Loxl2',
'Lrp2',
'Caprin1',
'Nbr1',
'Smad3',
'Man2c1',
'Mlh1',
'Map3k11',
'Mobp',
'Get3',
'Mtm1',
'Myo9a',
'Atf3',
'Atf4',
'Ncbp1',
'Ndufa2',
'Ndufb5',
'Ndufb8',
'Nit1',
'Nktr',
'Notch1',
'Pnp',
'Ror1',
'Oaz2',
'Orc1',
'Aco2',
'Aldh7a1',
'Oxa1l',
'Prdx1',
'Pak1',
'Ak3',
'Cops7a',
'Pdcl',
'Pcbp1',
'Acox1',
'Emc9',
'Txndc12',
'Klhl5',
'Aph1a',
'Rdh11',
'Hsd17b12',
'Ing4',
'Jpt1',
'Nusap1',
'Crim1',
'Pcsk5',
'Pipox',
'Cdk16',
'Cdk17',
'Mex3c',
'Ubr5',
'Nip7',
'Atp5pb',
'Hikeshi',
'Ufm1',
'Larp7',
'Pcf11',
'Nbas',
'Mrps23',
'Enpp2',
'Sufu',
'Cyb5r2',
'Uimc1',
'Wbp11',
'Arid4b',
'Cdk12',
'Rsf1',
'Phax',
'Cdk14',
'Serpina1',
'Pin4',
'Pitx2',
'Fxyd5',
'Rab4b',
'Exosc9',
'Pole3',
'Errfi1',
'Gdap1',
'Slc38a2',
'Pou2f1',
'Ccdc93',
'Pou5f1',
'Fbxl19',
'Mindy2',
'Rrn3',
'Trit1',
'Elp6',
'Ankhd1',
'Ino80d',
'Auh',
'Nsd3',
'Ppm1b',
'Tmem160',
'Tipin',
'Znf770',
'Zscan2',
'Pih1d1',
'Ppp2r3c',
'C14orf119',
'Ppp1r2',
'Rnf31',
'Akirin2',
'Ppp1r10',
'Rbm23',
'Dars2',
'Ppp2r1a',
'Rif1',
'Ric8b',
'Ppp2r1b',
'Resf1',
'Dppa4',
'Ppp2r3a',
'Vrtn',
'Ppp2r5c',
'Ube2w',
'Lsg1',
'Znf331',
'Prcc',
'Fem1a',
'Stap2',
'Osgep',
'Hif1an',
'Iws1',
'Rbm22',
'Yju2',
'Polr3e',
'Prkar1a',
'Vps35',
'Naxd',
'Ap5m1',
'Rcor3',
'Znf701',
'H2aj',
'Prr11',
'Foxj2',
'Kdm3a',
'Eapp',
'Cisd1',
'Mynn',
'Zc4h2',
'Prnp',
'Prpsap1',
'Prss8',
'Psen2',
'Psmb1',
'Ubqln4',
'Bdh2',
'Spire1',
'Exosc5',
'Smarcad1',
'Olfml3',
'Xab2',
'Psmg2',
'Kif15',
'Psmc2',
'Aven',
'Rab25',
'Mrpl47',
'Tp73-as1',
'Znf286a',
'Kiaa1143',
'Scaf4',
'Odf2l',
'Arid1b',
'Nufip2',
'Sema6a',
'Arrdc3',
'Ranbp10',
'Lrrn1',
'Ptn',
'Cachd1',
'Ptpn2',
'Ano8',
'Ptpn3',
'Scaf1',
'Sinhcaf',
'Bcat1',
'Rab5a',
'Rad23a',
'Rasa1',
'Rasgrf2',
'Bckdha',
'Senp2',
'Ccnd1',
'Rest',
'Rfx1',
'Rgs10',
'Tgif2',
'Sav1',
'Bcl9',
'Rpl7',
'Rpl9',
'Rpl15',
'Rpl30',
'Rpl36a',
'Rplp1',
'Rps3a',
'Rps18',
'Rps26',
'Rps29',
'Rtn2',
'Sort1',
'Vps52',
'Sall1',
'Sat1',
'Sc5d',
'Scnn1a',
'Cxcl5',
'Nsun3',
'Sdhd',
'Znf335',
'Prdm14',
'Lhpp',
'Set',
'Sfpq',
'Sfrp1',
'Sfrp2',
'Rab17',
'Srsf4',
'Noc3l',
'Srsf7',
'Sgta',
'Sh3gl3',
'Mospd3',
'Nucks1',
'St3gal2',
'Mrps11',
'Skil',
'Bmp2',
'Nol6',
'Rsrc2',
'Slc3a2',
'Coa7',
'Bmp7',
'Hltf',
'Plekha3',
'Rasl11b',
'Tmem108',
'Snapc1',
'Snapc3',
'Snrpa',
'Snrpd3',
'Snrpn',
'Snx1',
'Sox2',
'Sp2',
'Ssr4',
'Zfp36l1',
'Stat3',
'Stc1',
'Hspa13',
'Stxbp2',
'Klf5',
'Taf12',
'Tal1',
'Taldo1',
'Tarbp2',
'Tbp',
'Tcf7l2',
'Btg1',
'Tcf20',
'Ppp1r11',
'Tdgf1',
'Bub1b',
'Lefty2',
'Thbs2',
'Thop1',
'Tia1',
'Tial1',
'Timp4',
'Tle1',
'Tle2',
'Tle3',
'Tnfaip2',
'Top2a',
'Tpm3',
'Hsp90b1',
'Tubg1',
'Txnrd1',
'Ubc',
'Ube2d3',
'Ubp1',
'Ufd1',
'Ugt8',
'Vasp',
'Vim',
'Zic1',
'Zic2',
'Zic3',
'Ca2',
'Ca4',
'Znf140',
'Cacna1a',
'Znf217',
'Map3k12',
'Cacna2d1',
'Usp7',
'Trir',
'Scnm1',
'Dda1',
'Tmem109',
'Dscc1',
'Wdr77',
'Phf23',
'Gnptab',
'Lrfn3',
'Obi1',
'Vcpkmt',
'Hmbox1',
'C1orf54',
'Akirin1',
'Prkrip1',
'Tbl1xr1',
'Tbc1d17',
'Znf668',
'Fzd3',
'Katnbl1',
'Vash2',
'Dcakd',
'Nanog',
'Kiaa0319l',
'Kat6a',
'Dhdds',
'Jade1',
'Grhl2',
'Rmi1',
'Dglucy',
'Pif1',
'Mus81',
'Fbxo11',
'Mllt10',
'Dcaf11',
'Calm2',
'Calr',
'Anp32a',
'Slc7a5',
'Taf15',
'C1orf21',
'Urm1',
'Fip1l1',
'Diaph3',
'Med25',
'Slc7a5p1',
'Mkks',
'Capza2',
'Cdc7',
'Cdc45',
'Eomes',
'Fzd1',
'Fzd7',
'H2ac18',
'Tcf7l1',
'Sf3b5',
'Abhd11',
'H2bc21',
'Gucd1',
'H4c3',
'Usp44',
'Arid5b',
'Ciao2a',
'Casp9',
'Poldip3',
'Naa38',
'Akt1s1',
'Plpp5',
'Mrpl43',
'Ttf2',
'Tead2',
'Gtpbp3',
'Hdgfl2',
'Ogt',
'Cdc42bpa',
'Lingo1',
'Cep89',
'Zfyve19',
'Prpf38a',
'Mpnd',
'Ajuba',
'Smim3',
'Pik3r3',
'Parg',
'Zcchc3',
'Zcrb1',
'Ap3b1',
'Cdc14b',
'Plpp1',
'Uso1',
'Eif3f',
'B3galt4',
'Gbf1',
'Ripk1',
'Trim24',
'Sap30',
'Hesx1',
'Tsc22d1',
'Per2',
'Dph6',
'Spag9',
'Cep95',
'Pip4p1',
'Btf3l4',
'Nemf',
'Tmsb10',
'Cables1',
'Bub3',
'Ddx21',
'Znf300',
'Large1',
'Lrat',
'Pnma1',
'Msc',
'Dhrs3',
'H2ac25',
'Pgap3',
'B4galt6',
'Cnot8',
'Armc6',
'Cer1',
'Sfxn1',
'Paxbp1',
'Cdyl',
'Med17',
'Ggps1',
'Atp6v1g1',
'Cep41',
'Rbm39',
'Kif20b',
'Nfe2l3',
'Rnf14',
'Fez1',
'Morf4l2',
'Mdc1',
'Znf516',
'Prorp',
'Pum1',
'Tmem63a',
'Znf646',
'Hdac9',
'Kntc1',
'Tcaf1',
'Susd6',
'Bclaf1',
'Dhx38',
'Mtss1',
'Spcs2',
'Arhgap11a',
'Cdk1',
'Zeb2',
'Heph',
'Epm2aip1',
'Smg7',
'Med12']

# %%
Oct4_target_genes = ['Naalad2',
'Arpc5',
'Zmpste24',
'Trim22',
'Hmg20a',
'Timm23b',
'Nebl',
'Sorbs1',
'Polr3g',
'Oga',
'Blcap',
'Gadd45g',
'Maged2',
'Stmn2',
'Il1rapl1',
'Hhla3',
'Ficd',
'Nudt5',
'Fzd10',
'Rnf24',
'Cavin3',
'Dusp12',
'Add3',
'Naa30',
'Tmem170a',
'Col12a1',
'Osr1',
'Aasdh',
'Wdr36',
'Cpt1a',
'Icmt-dt',
'Ccn2',
'Commd7',
'Irx2',
'Rdh10',
'Tstd2',
'Spred1',
'Dpysl2',
'Dpysl3',
'Dtna',
'Dusp6',
'Eif2s1',
'Elavl2',
'Epha1',
'Fgf2',
'Fgfr1',
'Fgfr2',
'Zhx2',
'Dkk1',
'Slc4a1ap',
'Wdfy3',
'Foxo1',
'Phf8',
'Kank1',
'Sulf1',
'Dnajc9',
'Fbxw11',
'Obsl1',
'Smg5',
'Pip5k1c',
'Frat2',
'Commd3',
'Slc44a1',
'Icmt',
'Chst5',
'Mkrn1',
'Ssbp2',
'Zkscan5',
'Fus',
'Cby1',
'Rad54b',
'Bambi',
'Txn2',
'Abtb2',
'Sgms1',
'Pnisr',
'Gap43',
'Prpf31',
'Kifbp',
'Gas1',
'Phgdh',
'Gata6',
'Gja1',
'Ankrd1',
'Snx5',
'Tjp3',
'Gpc3',
'Gldc',
'Tnrc6a',
'Kcnmb4',
'Gng10',
'Gps1',
'Grid2',
'Mrpl13',
'Atad2',
'Tfpt',
'Tra2a',
'Has2',
'Hhex',
'Hmgb2',
'Hoxb5',
'Tnc',
'Id2',
'Ifi16',
'Amigo2',
'Ska2',
'Jarid2',
'Jund',
'Jup',
'Kcnn2',
'Kdr',
'Ier5l',
'Lama4',
'Med11',
'Man2c1',
'Mcc',
'Meis2',
'Map3k3',
'Mmp2',
'Mtm1',
'Ncbp1',
'Nefm',
'Nefl',
'Ror1',
'Orc1',
'Pak1',
'Myef2',
'Pdcl',
'Klhl5',
'Jpt1',
'Dbr1',
'Pbdc1',
'Pipox',
'Cdk17',
'Ubr5',
'Atp6v1d',
'Ufm1',
'Enpp2',
'Cdk14',
'Exosc9',
'Pou5f1',
'Ankhd1',
'Auh',
'Wdr70',
'Rif1',
'Ric8b',
'Ppp2r1b',
'Resf1',
'Dppa4',
'Ppp2r3a',
'Lsg1',
'Tbc1d22b',
'Nploc4',
'Rbm22',
'Yju2',
'Naxd',
'Tmem30a',
'H2aj',
'Prr11',
'Kdm3a',
'Klhl4',
'Pard3',
'Prps1',
'Psma3',
'Smarcad1',
'Olfml3',
'Kif15',
'Kiaa1143',
'Arid1b',
'Lrrn1',
'Ptpn2',
'Ano8',
'Rab5a',
'Rad51c',
'Rasgrf2',
'Rest',
'Rfng',
'Tgif2',
'Rpl32',
'Rps3a',
'Rps18',
'Vps52',
'Sall1',
'Prdm14',
'Lhpp',
'Set',
'Sfrp1',
'Sfrp2',
'Srsf4',
'Sox17',
'Inf2',
'Zdhhc6',
'Nucks1',
'Ddx31',
'Armcx5',
'Skil',
'Acd',
'Bmp7',
'Snrpn',
'Sox2',
'Zfp36l1',
'Stat3',
'Klf5',
'Taf12',
'Tal1',
'Taldo1',
'Tcf4',
'Tcf12',
'Tcf20',
'Tdgf1',
'Bub1b',
'Nr2f2',
'Lefty2',
'Thbs2',
'Tle3',
'Top2a',
'Trps1',
'Ube2d3',
'Wee1',
'Zic1',
'Zic2',
'Zic3',
'Ca2',
'Ca4',
'Cacna2d1',
'Usp7',
'Gnptab',
'Lrfn3',
'Obi1',
'Efl1',
'Prkrip1',
'Tbl1xr1',
'Katnbl1',
'Nanog',
'Cntnap3',
'Kat6a',
'Dhdds',
'Jade1',
'Grhl2',
'Mllt10',
'Urm1',
'Slirp',
'Capza2',
'Cdc7',
'Eomes',
'Tcf7l1',
'H2bc21',
'Usp44',
'Coa8',
'Gtpbp3',
'Lingo1',
'Prpf38a',
'Smim3',
'Parg',
'Cdc14b',
'Klf7',
'Plpp1',
'B3galt4',
'Trim24',
'Hesx1',
'Alkbh1',
'Tsc22d1',
'Cdc123',
'Dph6',
'Spag9',
'Cables1',
'Wdr20',
'Bub3',
'Large1',
'Lrat',
'Msc',
'Dhrs3',
'Trip4',
'Gtf3c4',
'Plaa',
'Sfxn1',
'Cdyl',
'Bag5',
'Entpd1',
'Atp6v1g1',
'Gtpbp1',
'Nfe2l3',
'Fez1',
'Pclaf',
'Ist1',
'Zeb2',
'Supt7l',
'Josd1',
'Med12',
'Cdh1']

# %%
sc.tl.score_genes(adata,Oct4_target_genes, score_name='Oct4_target_score')

# %%
sc.tl.score_genes(adata,Sox2_target_genes, score_name='Sox2_target_score')

# %%
sc.tl.score_genes(adata,Nanog_target_genes, score_name='Nanog_target_score')

# %%
#AT2 cell subsets

# %%
adata_subset = adata[adata.obs['leiden'].isin(['0', '2', '3', '4', '5', '6', '10', '15'])]

# %%
sc.pl.dotplot(adata_subset, ['Sox2_target_score',
    'Oct4_target_score',
                     'Nanog_target_score'], groupby='batch', vmin=0, vmax=0.1,swap_axes=True,
             save='Dotplot_AT2_target_score.pdf')

# %%
sc.pl.violin(adata_subset, ['Sox2_target_score',
    'Oct4_target_score',
                     'Nanog_target_score'], groupby = 'batch', vmax=0.15,
             save='violin_AT2_target_score2.pdf')

# %%
#WNT signaling

# %%
bcat_target_genes = ['Adam17',
'Axin1',
'Axin2',
'Ccnd2',
'Csnk1e',
'Ctnnb1',
'Cul1',
'Dkk1',
'Dkk4',
'Dll1',
'Dvl2',
'Frat1',
'Fzd1',
'Fzd8',
'Gnai1',
'Hdac11',
'Hdac2',
'Hdac5',
'Hey1',
'Hey2',
'Jag1',
'Jag2',
'Kat2a',
'Lef1',
'Maml1',
'Myc',
'Ncor2',
'Ncstn',
'Nkd1',
'Notch1',
'Notch4',
'Numb',
'Ppard',
'Psen2',
'Ptch1',
'Rbpj',
'Skp2',
'Tcf7',
'Tp53',
'Wnt1',
'Wnt5b',
'Wnt6']

# %%
sc.tl.score_genes(adata_subset,bcat_target_genes, score_name='bcat_target_score')

# %%
sc.pl.dotplot(adata_subset, ['Axin2', 'Myc', 'Ascl2', 'Cd44', 'Ccnd1', 'Jag1', 'Bmp4', 'Met', 'bcat_target_score'], groupby='batch', vmin=0, vmax=0.1,swap_axes=True,
             save='Dotplot_AT2_WNT3.pdf')
